# %%
class ProgramZCzasem:
    #Lista kolumn, które zawieraja dane typu integer lub string
    kolumnyInt = ['Clothing ID','Age','Rating', 'Recommended IND','Positive Feedback Count']
    kolumny_string = ['Title', 'Review Text', 'Division Name', 'Department Name', 'Class Name']
    
    #Tekst menu dla klucza menu '2' stworzony w oparciu o listę kolumn typu integer
    kolumnyIntTekstMenu = '\nŚwietnie! \
                           \nCzyli chcesz wiedzieć więcej o liczbach w naszej tabeli, a oto i dostępne kolumny:'
    for i, col in enumerate(kolumnyInt):
        kolumnyIntTekstMenu += f'\n{str(i+1)} - {col}'
        
    #Dodatkowy parametr potrzebny do wykonania niektórych poleceń (np. informacja o wybranej kolumnie)
    parametrDodatkowy = ''
    
    #Struktura menu użytkownika
    #1. Klucz słownika określa położenie w menu, np. klucz '14' określa, że aby dostać się do tego menu należy wybrać
    #pierwszą opcję w pierwszym menu, a następnie opcję 4 w drugim menu. 
    #2. Wartości słownika są uporządkowane na dwa sposoby:
    #a) 'typ' = 'menu' -> określa, że zostanie wyświetlone menu, w którym użytkownik będzie musial dokonać wyboru.
    #Oczekiwany wybór jest określony 'oczekiwanaOdp': 'menu_int' - użytkownik powinien wybrać liczbę z menu, 
    #'zmienna_int' - użytkownik powinien wprowadzić wartość typu integer (będzie służyła jako parametr dodatkowy),
    #'zmienna_string' - użytkownik powinien wprowadzić tekst (będzie służył jako parametr dodatkowy). 
    #Wartość klucza 'tekst' określa tekst menu, który zostanie wyświetlony
    #b) 'typ' = 'akcja' -> określa, że na danym poziomie menu się kończy i zostanie wykonane polecenie.
    #3. Wartość 0 w kluczach słownika określa, że od użytkownika oczekiwano odpowiedzi typu zmienna_int lub zmienna_string
    #i jego wybór został zapamiętany w zmiennej parametrDodatowy
    menu = {
        '' :  {'typ' : 'menu',
               'oczekiwanaOdp' : 'menu_int',
               'tekst' : 
                   '\nMenu początkowe: \
                    \n1 - Ogólne informacje o danych \
                    \n2 - Szczegółowe informacje o kolumnach typu integer \
                    \n3 - Szczegółowe informacje o kolumnach typu string \
                    \nW każdym momencie wybierz: \
                    \nZ - aby przejść do poprzedniego menu \
                    \nX - aby wyjść z programu'},
        '1' : {'typ' : 'menu',
               'oczekiwanaOdp' : 'menu_int',
               'tekst' : 
                   '\nWybrałeś ogólne informacje o danych. \
                    \nWybierz interesujące Cię informacje: \
                    \n1 - Opis danych \
                    \n2 - Pierwsze wiersze tabeli \
                    \n3 - Ogólne statystyki opisowe \
                    \n4 - Podsumowanie danych'},
        '11' : {'typ' : 'akcja',
               'akcja' : 'akcja_11'},
        '12' : {'typ' : 'akcja',
               'akcja' : 'akcja_12'},
        '13' : {'typ' : 'akcja',
               'akcja' : 'akcja_13'},
        '14' : {'typ' : 'akcja',
               'akcja' : 'akcja_14'},
        '2' : {'typ' : 'menu',
               'oczekiwanaOdp' : 'zmienna_int',
               'tekst' : 
                   f'{kolumnyIntTekstMenu}'},
        '20' : {'typ' : 'menu',
                'oczekiwanaOdp' : 'menu_int',
                'tekst' :
                    f'\nWybrana kolumna to {parametrDodatkowy} \
                     \nJakiej informacji potrzebujesz ? \
                     \n1 - Wszystkie dane z kolumny \
                     \n2 - Szczegółowe dane statystyczne \
                     \n3 - Wykres skrzynkowy \
                     \n4 - Rozkład obserwacji \
                     \n5 - Jądrowy estymator gęstości'},
        '201' : {'typ' : 'akcja',
               'akcja' : 'akcja_201'},
        '202' : {'typ' : 'akcja',
               'akcja' : 'akcja_202'},
        '203' : {'typ' : 'akcja',
               'akcja' : 'akcja_203'},
        '204' : {'typ' : 'akcja',
               'akcja' : 'akcja_204'},
        '205' : {'typ' : 'akcja',
               'akcja' : 'akcja_205'},
        '3' : {'typ' : 'menu',
                'oczekiwanaOdp' : 'menu_int',
                'tekst' : 
                   '\nChcesz się bliżej przyjrzeć komentarzom? Super! \
                    \nPrzed Tobą kilka możliwości: \
                    \n1 - Informacje statystyczne o komentarzach \
                    \n2 - Przeczytaj konkretny komentarz \
                    \n3 - Wyszukaj komentarze zawierające konkretne słowo \
                    \n4 - Zobacz chmurę najpopularniejszych słów w komentarzach \
                    \n5 - Przetestuj biblioteki oceniające, czy dany tekst jest pozytywny, czy negatywny, wpisując własną sentencje'},
        '31' : {'typ' : 'akcja',
                'akcja' : 'akcja_31'},
        '32' : {'typ' : 'menu',
                'oczekiwanaOdp' : 'zmienna_int',
                'tekst' : 'Podaj numer z przedziału (1-23485), aby przeczytać konkretny komentarz.'},
        '320' : {'typ' : 'akcja',
                'akcja' : 'akcja_320'},

        '33' : {'typ' : 'menu',
                'oczekiwanaOdp' : 'zmienna_string',
                'tekst' : 'Podaj słowo kluczowe.'},
        '330' : {'typ' : 'akcja',
                'akcja' : 'akcja_330'},
        '34' : {'typ' : 'akcja',
                'akcja' : 'akcja_34'},
        '35' : {'typ' : 'menu',
                'oczekiwanaOdp' : 'zmienna_string',
                'tekst' : 'Podaj tekst.'},
        '350' : {'typ' : 'akcja',
                'akcja' : 'akcja_350'},
        'X' : {'typ' : 'menu',
               'tekst' : 'Wychodzę z programu. Do widzenia.',
               'oczekiwanaOdp' : ''
              }
    }
       
    def __init__(self, sciezkaDoDanych):
        #Wczytaj i wyczyść dane
        self.dane = pd.read_csv(sciezkaDoDanych)
        self.dane["Review Text"]=self.dane["Review Text"].fillna("0")
        #Zmienna binarna określająca czy program powinien dalej działać. Przyjmuje wartość False jeśli użytkownik
        #zdecydował się wyjść z programu
        self.ProgramDziala = True
        #Lista zawierająca wybrane opcje w menu.
        self.pozycjaMenu = []
        #Zmienna określająca oczekiwany typ odpowiedzi od użytkownika
        self.oczekiwanaOdp = 'menu_int'
    
    #Metoda do poproszenia użytkownika o dokonanie wyboru.
    def poprosOOdp(self):
        self.odpowiedz = input('\n################Twoj wybor:')
    
    #Metoda do sprawdzenia poprawności dokonanego wyboru
    def zwalidujOdpowiedz(self):
        #Użytkownik zdecydował wyjść z programu
        if self.odpowiedz.upper() == 'X':
            self.pozycjaMenu = ['X']
            self.ProgramDziala = False
        #Użytkownik zdecydował wrócić na wyższy poziom menu
        elif self.odpowiedz.upper() == 'Z':
            try:
                del self.pozycjaMenu[-1]
                print('\nIdę poziom wyżej.')
            except IndexError:
                print('\nNie możesz iść wyżej. Wyświetlę dla Ciebie menu początkowe jeszcze raz.')
        #Użytkownik powinien wybrać opcję z menu. 
        elif self.oczekiwanaOdp == 'menu_int':
            try:
                self.odpowiedz = int(self.odpowiedz)
                self.pozycjaMenu.append(self.odpowiedz)
                print(f'\nTwój wybór to: {self.odpowiedz}')
            except:
                print('\nUps! Podałeś niepoprawną odpowiedź. Wyświetlę dla Ciebie menu jeszcze raz.')
        #Użytkownik powinien wprowadzić liczbę (np.wybrać kolumnę)
        elif self.oczekiwanaOdp == 'zmienna_int':
            try:
                self.odpowiedz = int(self.odpowiedz)
                self.parametrDodatkowy = self.odpowiedz
                self.pozycjaMenu.append(0)
                print(f'\nTwój wybór to: {self.odpowiedz}')
            except:
                print('\nUps! Podałeś niepoprawną odpowiedź. Wyświetlę dla Ciebie menu jeszcze raz.')
        #Użytkownik powinien wprowadzić tekst
        elif self.oczekiwanaOdp == 'zmienna_string':
            try:
                self.parametrDodatkowy = self.odpowiedz
                self.pozycjaMenu.append(0)
                print(f'\nTwój wybór to: {self.odpowiedz}')
            except:
                print('\nUps! Podałeś niepoprawną odpowiedź. Wyświetlę dla Ciebie menu jeszcze raz.')
        
        #Sprawdzenie czy wybrana opcja znajduje się w menu
        
        #Połącz wartości listy zawierającej pozycję w menu, aby móc przeszukać słownik menu
        pozycjaMenuString = ''.join([str(i) for i in self.pozycjaMenu])
        if not pozycjaMenuString in self.menu.keys():
            del self.pozycjaMenu[-1]
            print('\nUps! Podałeś niepoprawną odpowiedź. Wyświetlę dla Ciebie menu jeszcze raz.')
    
    #Metoda do wyświetlemoa menu lub uruchomienia polecenia (akcji) w zależności od położenia w menu
    def Wykonaj(self):
        #połącz wartości listy zawierającej pozycję w menu, aby móc przeszukać słownik menu
        pozycjaMenuString = ''.join([str(i) for i in self.pozycjaMenu])
    
        if self.menu[pozycjaMenuString]['typ'] == 'menu':
            #Wyświetl obecny poziom menu
            print(f'Poziom menu: {len(pozycjaMenuString) + 1}')
            #Wyświetl tekst menu
            print(self.menu[pozycjaMenuString]['tekst'])
            #Wyświetl obecny poziom menu
            print(f'Poziom menu: {len(pozycjaMenuString) + 1}')
            #Zapamiętaj typ kolejnej oczekiwanej odpowiedzi
            self.oczekiwanaOdp = self.menu[pozycjaMenuString]['oczekiwanaOdp']
        elif self.menu[pozycjaMenuString]['typ'] == 'akcja':
            #Wykonaj polecenie przypisane do obecnego miejsca w menu
            self.WykonajAkcje(self.menu[pozycjaMenuString]['akcja'])
            #Po wykonaniu polecenia wróć do ostatniego menu
            del self.pozycjaMenu[-1]
            #Wyświetl ostatnie menu
            self.Wykonaj()
    
    #Metoda z definicją poleceń w zależności od obecnego miejsca w menu
    def WykonajAkcje(self, akcja):
        if akcja == 'akcja_11':
            print("Wybrałeś opis danych:\n")
            print("Dane pochodzą ze strony: \n'www.kaggle.com/nicapotato/womens-ecommerce-clothing-reviews'\n")        
            print("Jest to zestaw danych E-Commerce dotyczący odzieży damskiej, zawierający recenzje klientów.")
            print("Z racji tego, że są to prawdziwe dane handlowe, zostały zanonimizowane, a odniesienia do firmy w tekście i treści przeglądu zostały zastąpione nazwą'sprzedawca detaliczny'\n")
            print("Ten zestaw danych zawiera 23486 wierszy i 10 zmiennych cech. Każdy wiersz odpowiada opinii klienta i zawiera zmienne:")
            print("Identyfikator odzieży, wiek klienta, tytuł komentarza, tekst komentarza, ocena, informacja o poleceniu/niepoleceniu produktu, liczba pozytywnych opinii, nazwa grupy, działu, kategorii ubrania\n")
        elif akcja == 'akcja_12':
            print("Wybrałeś podgląd pierwszych wierszy tabeli:\n")
            print(self.dane.head())
        elif akcja == 'akcja_13':
            print("Wybrałeś ogólne statystyki opisowe:\n")
            print(self.dane.describe())
        elif akcja == 'akcja_14':
            print("Wybrałeś podsumowanie danych:\n")
            print(self.dane.info())
        elif akcja == 'akcja_201':
            #Dodatkowo sprawdzenie czy wybrano poprawny numer kolumny
            try:
                print("LP.",self.kolumnyInt[self.parametrDodatkowy-1])
                print(self.dane[self.kolumnyInt[self.parametrDodatkowy-1]])
            except IndexError:
                print('Wybrałeś niepoprawną kolumnę. Wróć do poprzedniego menu i wybierz poprawny numer kolumny.')
        elif akcja == 'akcja_202':
            #Dodatkowo sprawdzenie czy wybrano poprawny numer kolumny
            try:    
                print(self.dane.loc[:,self.kolumnyInt[self.parametrDodatkowy-1]].describe())
            except IndexError:
                print('Wybrałeś niepoprawną kolumnę. Wróć do poprzedniego menu i wybierz poprawny numer kolumny.')
        elif akcja == 'akcja_203':
            #Dodatkowo sprawdzenie czy wybrano poprawny numer kolumny
            try:
                color = dict(markerfacecolor='r', marker='s')
                fig2, ax2 = plt.subplots()
                ax2.set_title(self.kolumnyInt[self.parametrDodatkowy-1])
                ax2.boxplot(self.dane[self.kolumnyInt[self.parametrDodatkowy-1]], notch=True, vert=False, flierprops=color)
                plt.show()
            except IndexError:
                print('Wybrałeś niepoprawną kolumnę. Wróć do poprzedniego menu i wybierz poprawny numer kolumny.')
        elif akcja == 'akcja_204':
            #Dodatkowo sprawdzenie czy wybrano poprawny numer kolumny
            try:
                sns.distplot(self.dane[self.kolumnyInt[self.parametrDodatkowy-1]])
                plt.show()
            except IndexError:
                print('Wybrałeś niepoprawną kolumnę. Wróć do poprzedniego menu i wybierz poprawny numer kolumny.')
        elif akcja == 'akcja_205':
            #Dodatkowo sprawdzenie czy wybrano poprawny numer kolumny
            try:
                sns.distplot(self.dane[self.kolumnyInt[self.parametrDodatkowy-1]], kde=True,kde_kws={"color": "b", "alpha":0.3, "linewidth": 5, "shade":True })
                plt.show()
            except IndexError:
                print('Wybrałeś niepoprawną kolumnę. Wróć do poprzedniego menu i wybierz poprawny numer kolumny.')
        elif akcja == 'akcja_31':
            print("{} % klientów poleca zakupiony produkt".format(round(self.dane["Recommended IND"].mean()*100,2)))
            print("Średnia ocena produktów: {}".format(round(self.dane["Rating"].mean(),2)))
            print("\nW przypadku braku komentarza:")
            print("{} % klientów poleca zakupiony produkt".format(round(self.dane[self.dane["Review Text"]=="0"]["Recommended IND"].mean()*100,2)))
            print("Średnia ocena produktów: {}".format(round(self.dane[self.dane["Review Text"]=="0"]["Rating"].mean(),2)))
            print("\nNajdłuższy komentarz ma {} znaków".format(round(pd.Series(self.dane["Review Text"].str.len()).max(),0)))
            print("Średnia liczba znaków w komentarzach: {}".format(round(pd.Series(self.dane["Review Text"].str.len()).mean(),0)))
        elif akcja == 'akcja_320':
            try:
                self.parametrDodatkowy = int(self.parametrDodatkowy)
                if self.parametrDodatkowy > 0 and self.parametrDodatkowy <= 23485:
                    text = self.dane["Review Text"][self.parametrDodatkowy-1]
                    rekomendacja = self.dane["Recommended IND"][self.parametrDodatkowy-1]
                    print(f"Komentarz numer {self.parametrDodatkowy}:\n\n {text}")
                    print(f"\nRekomendajca klienta: {'Tak' if rekomendacja == 1 else 'Nie'}")
                    print(f"\nRekomendacja według biblioteki Text Blob: {'Tak' if self.sentiment_text_blob(text)== 1 else 'Nie'}")
                    print(f"\nRekomendacja według biblioteki Vader Sentiment: {'Tak' if self.sentiment_vader(text) == 1 else 'Nie'}")
                else:
                    print("Podałeś złą wartość")
            except ValueError:
                print(f"{self.parametrDodatkowy} - nie jest poprawną warością")
        elif akcja == 'akcja_330':
            pd.set_option('display.max_colwidth', -1)
            wynik_index = self.dane['Review Text'].str.contains(self.parametrDodatkowy)
            if self.dane["Review Text"][self.dane.index[wynik_index]].empty:
                print(f"Nie znaleziono komentarza ze slowem {self.parametrDodatkowy}") 
            else:
                print(self.dane["Review Text"][self.dane.index[wynik_index]]+ "\n")
        elif akcja == 'akcja_34':
            text = ' '.join(self.dane["Review Text"])
            wordcloud = WordCloud(width=600, height=300).generate(text)
            plt.figure( figsize=(10,5), facecolor='k')
            plt.imshow(wordcloud)
            plt.axis("off")
            plt.tight_layout(pad=0)
            plt.show()
        elif akcja == 'akcja_350':
            print(f"Według biblioteki Vader: {self.sentiment_vader_neutral(self.parametrDodatkowy)}")
            print(f"Według biblioteki Text Blob: {self.sentiment_text_blob_neutral(self.parametrDodatkowy)}")
        else:
            print('Coś poszło nie tak jak powinno. Wyświetlę dla Ciebie menu jeszcze raz.')
    
    def sentiment_vader(self, sentence):
        sid = SentimentIntensityAnalyzer()
        snt = sid.polarity_scores(sentence)["compound"]
        if snt >= 0:
            return 1
        else:
            return 0
    
    def sentiment_vader_neutral(self, sentence):
        sid = SentimentIntensityAnalyzer()
        vs = sid.polarity_scores(sentence)["compound"]
        if vs == 0:
            return "Zdanie neutralne"
        elif vs > 0:
            return "Zdanie pozytywne"
        else:
            return "Zdanie negatywne"
    
    def sentiment_text_blob(self, sentence): 
        analysis = TextBlob(sentence)
        if analysis.sentiment.polarity >= 0: 
            return 1
        else:
            return 0
    
    def sentiment_text_blob_neutral(self, sentence): 
        analysis = TextBlob(sentence)
        if analysis.sentiment.polarity == 0: 
            return "Zdanie neutralne"
        elif analysis.sentiment.polarity > 0:
            return "Zdanie pozytywne"
        else:
            return "Zdanie negatywne"

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textblob import TextBlob
from wordcloud import WordCloud
# %matplotlib inline

# %%
#Stworzenie obiektu klasy
NaszProgram = ProgramZCzasem('/home/veeteque/InfoShare/Projekt_zczasem/LokalneProjekty/PythonStatystyka/DATA/Womens Clothing E-Commerce Reviews.csv')
#Wyświetlenie obecnego poziomu menu
NaszProgram.Wykonaj()

#Uruchomienie programu w pętli
while NaszProgram.ProgramDziala:
    NaszProgram.poprosOOdp()
    NaszProgram.zwalidujOdpowiedz()
    NaszProgram.Wykonaj()
# Out:
# Poziom menu: 1
#
# Menu początkowe:
# 1 - Ogólne informacje o danych
# 2 - Szczegółowe informacje o kolumnach typu integer
# 3 - Szczegółowe informacje o kolumnach typu string
# W każdym momencie wybierz:
# Z - aby przejść do poprzedniego menu
# X - aby wyjść z programu
# Poziom menu: 1
#
# ################Twoj wybor:3
#
# Twój wybór to: 3
# Poziom menu: 2
#
# Chcesz się bliżej przyjrzeć komentarzom? Super!
# Przed Tobą kilka możliwości:
# 1 - Informacje statystyczne o komentarzach
# 2 - Przeczytaj konkretny komentarz
# 3 - Wyszukaj komentarze zawierające konkretne słowo
# 4 - Zobacz chmurę najpopularniejszych słów w komentarzach
# 5 - Przetestuj biblioteki oceniające, czy dany tekst jest pozytywny, czy negatywny, wpisując własną sentencje
# Poziom menu: 2
#
# ################Twoj wybor:2
#
# Twój wybór to: 2
# Poziom menu: 3
# Podaj numer z przedziału (1-23485), aby przeczytać konkretny komentarz.
# Poziom menu: 3
#
# ################Twoj wybor:2
#
# Twój wybór to: 2
# Komentarz numer 2:
#
#  Love this dress!  it's sooo pretty.  i happened to find it in a store, and i'm glad i did bc i never would have ordered it online bc it's petite.  i bought a petite and am 5'8".  i love the length on me- hits just a little below the knee.  would definitely be a true midi on someone who is truly petite.
#
# Rekomendajca klienta: Tak
#
# Rekomendacja według biblioteki Text Blob: Tak
#
# Rekomendacja według biblioteki Vader Sentiment: Tak
# Poziom menu: 3
# Podaj numer z przedziału (1-23485), aby przeczytać konkretny komentarz.
# Poziom menu: 3
#
# ################Twoj wybor:1
#
# Twój wybór to: 1
# Komentarz numer 1:
#
#  Absolutely wonderful - silky and sexy and comfortable
#
# Rekomendajca klienta: Tak
#
# Rekomendacja według biblioteki Text Blob: Tak
#
# Rekomendacja według biblioteki Vader Sentiment: Tak
# Poziom menu: 3
# Podaj numer z przedziału (1-23485), aby przeczytać konkretny komentarz.
# Poziom menu: 3
#
# ################Twoj wybor:0
#
# Twój wybór to: 0
# Podałeś złą wartość
# Poziom menu: 3
# Podaj numer z przedziału (1-23485), aby przeczytać konkretny komentarz.
# Poziom menu: 3
#
# ################Twoj wybor:30000
#
# Twój wybór to: 30000
# Podałeś złą wartość
# Poziom menu: 3
# Podaj numer z przedziału (1-23485), aby przeczytać konkretny komentarz.
# Poziom menu: 3
#
# ################Twoj wybor:zxc
#
# Ups! Podałeś niepoprawną odpowiedź. Wyświetlę dla Ciebie menu jeszcze raz.
# Poziom menu: 3
# Podaj numer z przedziału (1-23485), aby przeczytać konkretny komentarz.
# Poziom menu: 3
#
# ################Twoj wybor:dupa
#
# Ups! Podałeś niepoprawną odpowiedź. Wyświetlę dla Ciebie menu jeszcze raz.
# Poziom menu: 3
# Podaj numer z przedziału (1-23485), aby przeczytać konkretny komentarz.
# Poziom menu: 3
#
# ################Twoj wybor:z
#
# Idę poziom wyżej.
# Poziom menu: 2
#
# Chcesz się bliżej przyjrzeć komentarzom? Super!
# Przed Tobą kilka możliwości:
# 1 - Informacje statystyczne o komentarzach
# 2 - Przeczytaj konkretny komentarz
# 3 - Wyszukaj komentarze zawierające konkretne słowo
# 4 - Zobacz chmurę najpopularniejszych słów w komentarzach
# 5 - Przetestuj biblioteki oceniające, czy dany tekst jest pozytywny, czy negatywny, wpisując własną sentencje
# Poziom menu: 2
#
# ################Twoj wybor:3
#
# Twój wybór to: 3
# Poziom menu: 3
# Podaj słowo kluczowe.
# Poziom menu: 3
#
# ################Twoj wybor:dupa
#
# Twój wybór to: dupa
# Nie znaleziono komentarza ze slowem dupa
# Poziom menu: 3
# Podaj słowo kluczowe.
# Poziom menu: 3
#
# ################Twoj wybor:pretty
#
# Twój wybór to: pretty
# 1        Love this dress!  it's sooo pretty.  i happened to find it in a store, and i'm glad i did bc i never would have ordered it online bc it's petite.  i bought a petite and am 5'8".  i love the length on me- hits just a little below the knee.  would definitely be a true midi on someone who is truly petite.\n
# 5        I love tracy reese dresses, but this one is not for the very petite. i am just under 5 feet tall and usually wear a 0p in this brand. this dress was very pretty out of the package but its a lot of dress. the skirt is long and very full so it overwhelmed my small frame. not a stranger to alterations, shortening and narrowing the skirt would take away from the embellishment of the garment. i love the color and the idea of the style but it just did not work on me. i returned this dress.\n
# 10       Dress runs small esp where the zipper area runs. i ordered the sp which typically fits me and it was very tight! the material on the top looks and feels very cheap that even just pulling on it will cause it to rip the fabric. pretty disappointed as it was going to be my christmas dress this year! needless to say it will be going back.\n
# 11       This dress is perfection! so pretty and flattering.\n
# 13       Bought the black xs to go under the larkspur midi dress because they didn't bother lining the skirt portion (grrrrrrrrrrr).\r\nmy stats are 34a-28/29-36 and the xs fit very smoothly around the chest and was flowy around my lower half, so i would say it's running big.\r\nthe straps are very pretty and it could easily be nightwear too.\r\ni'm 5'6" and it came to just below my knees.\n
# 15       I took these out of the package and wanted them to fit so badly, but i could tell before i put them on that they wouldn't. these are for an hour-glass figure. i am more straight up and down. the waist was way too small for my body shape and even if i sized up, i could tell they would still be tight in the waist and too roomy in the hips - for me. that said, they are really nice. sturdy, linen-like fabric, pretty color, well made. i hope they make someone very happy!\n
# 21       I'm upset because for the price of the dress, i thought it was embroidered! no, that is a print on the fabric. i think i cried a little when i opened the box. it is still ver pretty. i would say it is true to size, it is a tad bit big on me, but i am very tiny, but i can still get away with it. the color is vibrant. the style is unique. skirt portion is pretty poofy. i keep going back and forth on it mainly because of the price, although the quality is definitely there. except i wish it were emb\n
# 54       Nice top. armholes are a bit oversized but as an older woman, i'm picky about that. the print is pretty and unusual. it just didn't look great on me. there's a slight peplum in the back that hangs nicely. it's a lightweight tee fabric that's opaque. i tried it on with a black bra which was barely visible. great for warmer climates but there are so many gorgeous tops out now, that i decided to return since summer is winding down. i do recommend.\n
# 59       I've been looking for bralettes that provide some support but not binding/tight for night time and casual wear. this is a light weight bra, could be a little more supportive. pretty color, with nice lines. only downside is the retailer tag on the back - itchy (i need to remove it.)\n
# Name: Review Text, Length: 2013, dtype: object
# Poziom menu: 3
# Podaj słowo kluczowe.
# Poziom menu: 3
# ################Twoj wybor:sold out
#
# Twój wybór to: sold out
# 7        I ordered this in carbon for store pick up, and had a ton of stuff (as always) to try on and used this top to pair (skirts and pants). everything went with it. the color is really nice charcoal with shimmer, and went well with pencil skirts, flare pants, etc. my only compaint is it is a bit big, sleeves are long and it doesn't go in petite. also a bit loose for me, but no xxs... so i kept it and wil ldecide later since the light color is already sold out in hte smallest size...\n
# 146      Some reviewers found this skirt to be on the smaller side, but for me, it was big,,, too bad the smaller size is sold out (well, all peittes are sold out). the length is also pretty long, below the knee, but in the narrow part still...so able to keep it. the colors are great. i brought it in the store to try on in front fo the stylists, adn they all loved it and told me to keep it... winner for sure!\n
# 157      So  disappointed that no where in the limiting did it mention this suit is australian in size!! i ordered the 10 (i'm usually an 8 but that was sold out) and the suit arrives and doesn't even fir over my hips. -- the label clearly says 10 australian us 6!  gutted that i have to return this suit because of this sizing issue.  the suit looks to be well made and the design is adorable of it only for.\n
# 180      Loved the green color, the cut is super flattering, but alas, i do need hte petite, ti was a bit long and i looked a little lost. unfrotuantely, the color is sold out in petite :-(\n
# 194      Dress ran very large in every way. beautiful design, lining and quality material. i should have sized down 2 sizes. item is now sold out.\n
# 266      This dress is incredible. i saw a sales girl wearing it in my local retailer and loved it! i bought it in the navy color, it's gorgeous in person, very bright, vibrant colors. i am 5'9 34 c bra 27 inch waist and the s was quite big on my waist. i kept it anyway because the xs has been sold out, and got it taken in a bit. i wore it while vacationing in mexico and it definitely turned heads, if you're thinking about buying this dress, do it, you won't regret it!\n
# 292      I love these. i'm between a 29 and 30 and as the 30s were sold out i had to go with the 29s. they fit well. as expected. very nice fabric. good design. have to wear a short shirt or one tucked in. fabric has a bit of stretch which is also nice.\n
# 411      I was able to snatch this dress up just before it sold out (and i see it's now back in stock!). the quality of the fabrics is outstanding, not flimsy at all. the top is stretchy. normally i would wear a 2 at retailer, but the only choice i had was 0 and it fit. i am 5'5" tall, 125 lbs. everything about this dress makes me smile and i can't wait to wear it to my holiday party! don't hesitate if you are on the fence.\n
# 583      Well made. made my hips looks giant. just not my style unfortunately. i'd have to work at preschool or on a ship to pull this off. i'm 5'3 120-123lbssize 6-8. i got the size 6 (not petite cuz they were sold out).\n
# 628      These sold out in my size 16 before i even knew they existed! (probably a great indication that your in-between and plus-size customers are hungry for more options from you). please restock so i can get in on this apparently-perfect pant!\n
# 681      I bought this dress in the cream color. it was sold out online in most sizes but i stumbled upon it in person and immediately had to have it. i'm usually xs or small, and bought the small. they did not have an xs available so i can't compare, but the small was flattering and comfortable. i'm 5'5" 120 (34c) and it falls perfectly at my ankles (no dragging) and looks great with simple, neutral sandals. as some reviewers have mentioned it has some weight to it, so it's probably not great for hot da\n
# 771      I saw the cream color in size regular small in the "only one left" section at my local store. i had my heart set on this dress all summer but it was sold out, so i was super excited to see it. the color is true cream, like linen color. i was surprised that the dress is very heavy, as heavy as a medium sized coat. i can't understand why it's so heavy because the top is sleeveless and the dress part is pretty sheer. the dress is about 2" pass my feet which i wouldn't mind having it hemmed, but the\n
# ...
# 23400    This top is very light weight and comfortable. i am normally a 8/10 in tops due to my bust size but ordered a 6 based on other reviews. it fits great. i really like the fit and the pattern. it has been a great summer shirt and i can see myself grabbing for it in the fall paired with skinny jeans and a cute bootie.\n
# 23403    I originally purchased this dress in a petite 6. i am 5'3", 125lbs with a 36" bust. the petite 6 was a bit too tight so i returned it and went up to a size 8. so happy i did! this dress drapes and flows beautifully and i find it immensely flattering to my hourglass figure. i also adore the floral print! one reviewer objected to the way the bodice drapes and the very small hook closure which seemed insufficient. i did not object to this characteristic. it fit me beautifully throughout the bodice/\n
# 23408    I love this dress but it definitely runs big. i bought a size small and i'm between a 4 and a 6 and will have to return for an xs. the top feels like it will fall down and i'm a size 34c\n
# 23415    Love it! i am 125# and usually a size 2-4 or 26-27 in bottoms. typically size up for holding horses. based on other reviews, i ordered this in a 2. it stretched just a bit after wearing all day, so i'm glad i didn't get my normal 4. the fit is great, quality is great. it dresses up for a casual office day, wearing well with boots and tights, and i imagine pairing with tshirt and flip flops over the summer. i unique piece that quickly became a favorite.\n
# 23419    This skirt is so cute. this is a staple to have in your wardrobe. i wear it with boots and boot socks. but tights for cold winter days as well as flip flops in the summer. i got my true size of 4. its fits perfectly. i love the length with a peek of leg when you walk!\n
# 23421    Love, love this tunic. my size 4 fits perfectly with a little room, material is very soft and very comfortable. could be worn with leggings or with a belt as a dress...so many options. so worth it!!!\n
# 23422    I'm undecided about this shirt. this design is absolutely beautiful. but the shirt is very very sheer and the front comes down so low in a curved hem line. so, when you wear the necessary base layer, the shirt extends several inches beyond that and it looks kind of odd. i really wish tiny would make some beautiful shirts like this that aren't sheer and have a shorter front. i purchased my regular size and it fits a little smaller than other tiny shirts i have purchased. since the shirt is so bea\n
# 23423    This top is similar to other tiny tops that i have ordered in the past...beautiful embroidery, great neutral and metallic color pallet that goes with everything, and light weight. the top does run small, so i needed the large size to accommodate my 38in bust plus a thin cami (shirt is see through). the large fit similarly to the fit on the model.\n
# 23425    A great long line bra! beautiful and well made however it's tough to get the fit perfectly right. i usually wear a 32 b or 34 a and am 115lbs. the small was the best fit as the 32 (xs) was a very small 32. i could almost say it more of a 30 if that's even a size. it also rubs my skin few places so definitely not meant to be worn for more than a few hours. otherwise i recommend it!\n
# 23428    I must say that at first i had mixed feelings about this sweater. i was actually going to return it because i was unsure about the style and color. the color is to me like a lavender mauv-ish color but the description is actually "natural" . i must admit that in some light it looks more brown then lavender . regardless i think that in itself tells you that this sweater is not like any other. i actually wear it as a coat and its become an essential part of my wardrobe. i found the size to be true\n
# 23437    This dress is so cute in the photo and fit true to size, but the material is slinky and felt cheap. the stitching was also poor quality. i am so thankful that retailer will let us order a batch, try on and return in store...this went back.\n
# 23448    I like the contrast of the skirt with the bodice, the length of the sleeves, adn the subtle cut out at the neck. the cut is very flattering, adn i am glad the daker color is at the top, hte bottome color would wash me out. i tried on the regular size nad i would not get a peitte in this as the size was the perfect length for me. petite would be too short for my liking. (regular hit just above the knee)\n
# 23449    I tried these on because the color is really pretty and fun, and who donse't want a pair of comfy/cute pants... but they looked awful on my muscular thighs... i don't think the cut will be falttering on 99% of the population. also, not as comfortable as they looked, the crotch seemed a little "low" on me, though the pants were in the correct size.\n
# 23450    I wanted to love this jacket. so soft and great color. unfortunately it is just too light weight. it is almost like shirt fabric. nice heft to the fabric though. nice length - accept the sleeves were short on me. i am 5'10 and 135lbs. the small was the right size. i was looking for something slightly warmer to layer.\n
# 23459    This is my new favorite dress! my only complaint is the slip is too small and the dress cannot be worn without it. i can't order a size up as the dress would then be huge. not sure what the solution is but the dress itself is stunning.\n
# 23463    These pants overall are very comfortable, but have an unusual fit. they tend to run a bit short, and i always have to get pants hemmed shorter, so if you have long legs or like more draping, you probably won't like these. they also ran a bit large in the waist and thigh, a bit puffy, i had to size down in order to get a good fit. very good quality, and cute design.\n
# 23467    I worry when i have an elastic waist, or something that resembles this, but the dress hangs like a dream.\nno puffing out, no gathers that you can see.\nit is not sheath, but not a line either, kind of in between, hits several inches above my knees, but perfect with some black tights for winter. i saw the note about grey, have to try it on agin in daylight, but i would say think black on the top, light camel color on the bottom\ni am 5'8, typically wear a size 12, and it was true to size for me\nthe\n
# 23469    My size was not available so based on reviews stating the bagginess of a certain area, i sized down and glad i did. i never size down because i do not like tight clothing, especially casual wear. nice muted print and good quality terry material. recommend, but size down if you want a more fitted feel.\n
# 23473    Great quality and extremely flattering. bonus that it is on sale. i felt like this dress was a godsend. i am five months pregnant and needed a dress that made me feel comfortable but not frumpy. i think i'll get a lot of mileage out of it, as there's enough stretch to get me through the next few months and then (hopefully!) i can wear it after too. also can be dressed up or down, so appropriate for many occasions. i believe it runs true to size (i sized up, from xs to s, for obvious reasons, but\n
# 23477    I'm so impressed with the beautiful color combinations and embroidery but disappointed in the rayon fabric used, especially at this price point.  the sleeveless sheer blue outer dress is a flowy swing silhouette that retains many wrinkles.  i have thick shoulders and upper arms, so the armholes cut into my armpits.  the silky rayon liner is a blush rose color with adjustable spaghetti straps.  the slip has no stretch and feels a bit tight on my chest.  i ordered size medium petite and my stats a\n
# Name: Review Text, Length: 7381, dtype: object
# Poziom menu: 3
# Podaj słowo kluczowe.
# Poziom menu: 3
# ################Twoj wybor:impressed with the beau
#
# Twój wybór to: impressed with the beau
# 23477    I'm so impressed with the beautiful color combinations and embroidery but disappointed in the rayon fabric used, especially at this price point.  the sleeveless sheer blue outer dress is a flowy swing silhouette that retains many wrinkles.  i have thick shoulders and upper arms, so the armholes cut into my armpits.  the silky rayon liner is a blush rose color with adjustable spaghetti straps.  the slip has no stretch and feels a bit tight on my chest.  i ordered size medium petite and my stats a\n
# Name: Review Text, dtype: object
# Poziom menu: 3
# Podaj słowo kluczowe.
# Poziom menu: 3
#
# ################Twoj wybor:z
#
# Idę poziom wyżej.
# Poziom menu: 2
#
# Chcesz się bliżej przyjrzeć komentarzom? Super!
# Przed Tobą kilka możliwości:
# 1 - Informacje statystyczne o komentarzach
# 2 - Przeczytaj konkretny komentarz
# 3 - Wyszukaj komentarze zawierające konkretne słowo
# 4 - Zobacz chmurę najpopularniejszych słów w komentarzach
# 5 - Przetestuj biblioteki oceniające, czy dany tekst jest pozytywny, czy negatywny, wpisując własną sentencje
# Poziom menu: 2
#
# ################Twoj wybor:4
#
# Twój wybór to: 4
# Poziom menu: 2
#
# Chcesz się bliżej przyjrzeć komentarzom? Super!
# Przed Tobą kilka możliwości:
# 1 - Informacje statystyczne o komentarzach
# 2 - Przeczytaj konkretny komentarz
# 3 - Wyszukaj komentarze zawierające konkretne słowo
# 4 - Zobacz chmurę najpopularniejszych słów w komentarzach
# 5 - Przetestuj biblioteki oceniające, czy dany tekst jest pozytywny, czy negatywny, wpisując własną sentencje
# Poziom menu: 2
#
# ################Twoj wybor:5
#
# Twój wybór to: 5
# Poziom menu: 3
# Podaj tekst.
# Poziom menu: 3
#
# ################Twoj wybor:good
#
# Twój wybór to: good
# Według biblioteki Vader: Zdanie pozytywne
# Według biblioteki Text Blob: Zdanie pozytywne
# Poziom menu: 3
# Podaj tekst.
# Poziom menu: 3
#
# ################Twoj wybor:good stuff
#
# Twój wybór to: good stuff
# Według biblioteki Vader: Zdanie pozytywne
# Według biblioteki Text Blob: Zdanie pozytywne
# Poziom menu: 3
# Podaj tekst.
# Poziom menu: 3
#
# ################Twoj wybor:fuck
#
# Twój wybór to: fuck
# Według biblioteki Vader: Zdanie negatywne
# Według biblioteki Text Blob: Zdanie negatywne
# Poziom menu: 3
# Podaj tekst.
# Poziom menu: 3
#
# ################Twoj wybor:able
#
# Twój wybór to: able
# Według biblioteki Vader: Zdanie neutralne
# Według biblioteki Text Blob: Zdanie pozytywne
# Poziom menu: 3
# Podaj tekst.
# Poziom menu: 3
#
# ################Twoj wybor:this dress is not that good
#
# Twój wybór to: this dress is not that good
# Według biblioteki Vader: Zdanie negatywne
# Według biblioteki Text Blob: Zdanie pozytywne
# Poziom menu: 3
# Podaj tekst.
# Poziom menu: 3
#
# ################Twoj wybor:this sweter is red
#
# Twój wybór to: this sweter is red
# Według biblioteki Vader: Zdanie neutralne
# Według biblioteki Text Blob: Zdanie neutralne
# Poziom menu: 3
# Podaj tekst.
# Poziom menu: 3
#
# ################Twoj wybor:this dress is red
#
# Twój wybór to: this dress is red
# Według biblioteki Vader: Zdanie neutralne
# Według biblioteki Text Blob: Zdanie neutralne
# Poziom menu: 3
# Podaj tekst.
# Poziom menu: 3
#
# ################Twoj wybor:this dress is black
#
# Twój wybór to: this dress is black
# Według biblioteki Vader: Zdanie neutralne
# Według biblioteki Text Blob: Zdanie negatywne
# Poziom menu: 3
# Podaj tekst.
# Poziom menu: 3
#
# ################Twoj wybor:this dress is big
#
# Twój wybór to: this dress is big
# Według biblioteki Vader: Zdanie neutralne
# Według biblioteki Text Blob: Zdanie neutralne
# Poziom menu: 3
# Podaj tekst.
# Poziom menu: 3
#
# ################Twoj wybor:this dress is too big
#
# Twój wybór to: this dress is too big
# Według biblioteki Vader: Zdanie neutralne
# Według biblioteki Text Blob: Zdanie neutralne
# Poziom menu: 3
# Podaj tekst.
# Poziom menu: 3
#
# ################Twoj wybor:i do not like it
#
# Twój wybór to: i do not like it
# Według biblioteki Vader: Zdanie negatywne
# Według biblioteki Text Blob: Zdanie neutralne
# Poziom menu: 3
# Podaj tekst.
# Poziom menu: 3
#
# ################Twoj wybor:i would not recommend it
#
# Twój wybór to: i would not recommend it
# Według biblioteki Vader: Zdanie negatywne
# Według biblioteki Text Blob: Zdanie neutralne
# Poziom menu: 3
# Podaj tekst.
# Poziom menu: 3
#
# ################Twoj wybor:z
#
# Idę poziom wyżej.
# Poziom menu: 2
#
# Chcesz się bliżej przyjrzeć komentarzom? Super!
# Przed Tobą kilka możliwości:
# 1 - Informacje statystyczne o komentarzach
# 2 - Przeczytaj konkretny komentarz
# 3 - Wyszukaj komentarze zawierające konkretne słowo
# 4 - Zobacz chmurę najpopularniejszych słów w komentarzach
# 5 - Przetestuj biblioteki oceniające, czy dany tekst jest pozytywny, czy negatywny, wpisując własną sentencje
# Poziom menu: 2
#
# ################Twoj wybor:x
# Poziom menu: 2
# Wychodzę z programu. Do widzenia.
# Poziom menu: 2
