# %%
class ProgramZCzasem:
    #Lista kolumn, które zawieraja dane typu integer lub string
    kolumnyInt = ['Clothing ID','Age','Rating', 'Recommended IND','Positive Feedback Count']
    kolumny_string = ['Title', 'Review Text', 'Division Name', 'Department Name', 'Class Name']
    
    #Tekst menu dla klucza menu '2' stworzony w oparciu o listę kolumn typu integer
    kolumnyIntTekstMenu = '\nŚwietnie! \
                           \nCzyli chcesz wiedzieć więcej o liczbach w naszej tabeli, a oto i dostępne kolumny:'
    for i, col in enumerate(kolumnyInt):
        kolumnyIntTekstMenu += f'\n{str(i+1)} - {col}'
        
        
    #Dodatkowy parametr potrzebny do wykonania niektórych poleceń (np. informacja o wybranej kolumnie)
    parametrDodatkowy = ''
    
    #Struktura menu użytkownika
    #1. Klucz słownika określa położenie w menu, np. klucz '14' określa, że aby dostać się do tego menu należy wybrać
    #pierwszą opcję w pierwszym menu, a następnie opcję 4 w drugim menu. 
    #2. Wartości słownika są uporządkowane na dwa sposoby:
    #a) 'typ' = 'menu' -> określa, że zostanie wyświetlone menu, w którym użytkownik będzie musial dokonać wyboru.
    #Oczekiwany wybór jest określony 'oczekiwanaOdp': 'menu_int' - użytkownik powinien wybrać liczbę z menu, 
    #'zmienna_int' - użytkownik powinien wprowadzić wartość typu integer (będzie służyła jako parametr dodatkowy),
    #'zmienna_string' - użytkownik powinien wprowadzić tekst (będzie służył jako parametr dodatkowy). 
    #Wartość klucza 'tekst' określa tekst menu, który zostanie wyświetlony
    #b) 'typ' = 'akcja' -> określa, że na danym poziomie menu się kończy i zostanie wykonane polecenie.
    #3. Wartość 0 w kluczach słownika określa, że od użytkownika oczekiwano odpowiedzi typu zmienna_int lub zmienna_string
    #i jego wybór został zapamiętany w zmiennej parametrDodatowy
    menu = {
        '' :  {'typ' : 'menu',
               'oczekiwanaOdp' : 'menu_int',
               'tekst' : 
                   '\nMenu początkowe: \
                    \n1 - Ogólne informacje o danych \
                    \n2 - Szczegółowe informacje o kolumnach typu integer \
                    \n3 - Szczegółowe informacje o kolumnach typu string \
                    \nW każdym momencie wybierz: \
                    \nZ - aby przejść do poprzedniego menu \
                    \nX - aby wyjść z programu'},
        '1' : {'typ' : 'menu',
               'oczekiwanaOdp' : 'menu_int',
               'tekst' : 
                   '\nWybrałeś ogólne informacje o danych. \
                    \nWybierz interesujące Cię informacje: \
                    \n1 - Opis danych \
                    \n2 - Pierwsze wiersze tabeli \
                    \n3 - Ogólne statystyki opisowe \
                    \n4 - Podsumowanie danych'},
        '11' : {'typ' : 'akcja',
               'akcja' : 'akcja_11'},
        '12' : {'typ' : 'akcja',
               'akcja' : 'akcja_12'},
        '13' : {'typ' : 'akcja',
               'akcja' : 'akcja_13'},
        '14' : {'typ' : 'akcja',
               'akcja' : 'akcja_14'},
        '2' : {'typ' : 'menu',
               'oczekiwanaOdp' : 'zmienna_int',
               'tekst' : 
                   f'{kolumnyIntTekstMenu}'},
        '20' : {'typ' : 'menu',
                'oczekiwanaOdp' : 'menu_int',
                'tekst' :
                    f'\nWybrana kolumna to {parametrDodatkowy} \
                     \nJakiej informacji potrzebujesz ? \
                     \n1 - Wszystkie dane z kolumny \
                     \n2 - Szczegółowe dane statystyczne \
                     \n3 - Wykres skrzynkowy \
                     \n4 - Rozkład obserwacji \
                     \n5 - Jądrowy estymator gęstości'},
        '201' : {'typ' : 'akcja',
               'akcja' : 'akcja_201'},
        '202' : {'typ' : 'akcja',
               'akcja' : 'akcja_202'},
        '203' : {'typ' : 'akcja',
               'akcja' : 'akcja_203'},
        '204' : {'typ' : 'akcja',
               'akcja' : 'akcja_204'},
        '205' : {'typ' : 'akcja',
               'akcja' : 'akcja_205'},
        '3' : {'typ' : 'menu',
                'oczekiwanaOdp' : 'menu_int',
                'tekst' : 
                   '\nChcesz się bliżej przyjrzeć komentarzom? Super! \
                    \nPrzed Tobą kilka możliwości: \
                    \n1 - Informacje statystyczne o komentarzach \
                    \n2 - Przeczytaj konkretny komentarz \
                    \n3 - Wyszukaj komentarze zawierające konkretne słowo \
                    \n4 - Zobacz chmurę najpopularniejszych słów w komentarzach \
                    \n5 - Przetestuj biblioteki oceniające, czy dany tekst jest pozytywny, czy negatywny, wpisując własną sentencje'},
        '31' : {'typ' : 'akcja',
                'akcja' : 'akcja_31'},
        '32' : {'typ' : 'menu',
                'oczekiwanaOdp' : 'zmienna_int',
                'tekst' : 'Podaj numer z przedziału (1-23485), aby przeczytać konkretny komentarz.'},
        '320' : {'typ' : 'akcja',
                'akcja' : 'akcja_320'},

        '330' : {'typ' : 'menu',
                'oczekiwanaOdp' : 'zmienna_string',
                'tekst' : 'Podaj słowo kluczowe.'},
        '33' : {'typ' : 'akcja',
                'akcja' : 'akcja_330'},
        '34' : {'typ' : 'akcja',
                'akcja' : 'akcja_34'},
        '350' : {'typ' : 'menu',
                'oczekiwanaOdp' : 'zmienna_string',
                'tekst' : 'Podaj tekst.'},
        '35' : {'typ' : 'akcja',
                'akcja' : 'akcja_350'},
        'X' : {'typ' : 'menu',
               'tekst' : 'Wychodzę z programu. Do widzenia.',
               'oczekiwanaOdp' : ''
              }
    }
       
    def __init__(self, sciezkaDoDanych):
        self.dane = pd.read_csv(sciezkaDoDanych)
        #Zmienna binarna określająca czy program powinien dalej działać. Przyjmuje wartość False jeśli użytkownik
        #zdecydował się wyjść z programu
        self.ProgramDziala = True
        #Lista zawierająca wybrane opcje w menu.
        self.pozycjaMenu = []
        #Zmienna określająca oczekiwany typ odpowiedzi od użytkownika
        self.oczekiwanaOdp = 'menu_int'
    
    #Metoda do poproszenia użytkownika o dokonanie wyboru.
    def poprosOOdp(self):
        self.odpowiedz = input('\n################Twoj wybor:')
    
    #Metoda do sprawdzenia poprawności dokonanego wyboru
    def zwalidujOdpowiedz(self):
        #Użytkownik zdecydował wyjść z programu
        if self.odpowiedz.upper() == 'X':
            self.pozycjaMenu = ['X']
            self.ProgramDziala = False
        #Użytkownik zdecydował wrócić na wyższy poziom menu
        elif self.odpowiedz.upper() == 'Z':
            try:
                del self.pozycjaMenu[-1]
                print('\nIdę poziom wyżej.')
            except IndexError:
                print('\nNie możesz iść wyżej. Wyświetlę dla Ciebie menu początkowe jeszcze raz.')
        #Użytkownik powinien wybrać opcję z menu. 
        elif self.oczekiwanaOdp == 'menu_int':
            try:
                self.odpowiedz = int(self.odpowiedz)
                self.pozycjaMenu.append(self.odpowiedz)
                print(f'\nTwój wybór to: {self.odpowiedz}')
            except:
                print('\nUps! Podałeś niepoprawną odpowiedź. Wyświetlę dla Ciebie menu jeszcze raz.')
        #Użytkownik powinien wprowadzić liczbę (np.wybrać kolumnę)
        elif self.oczekiwanaOdp == 'zmienna_int':
            try:
                self.odpowiedz = int(self.odpowiedz)
                self.parametrDodatkowy = self.odpowiedz
                self.pozycjaMenu.append(0)
                print(f'\nTwój wybór to: {self.odpowiedz}')
            except:
                print('\nUps! Podałeś niepoprawną odpowiedź. Wyświetlę dla Ciebie menu jeszcze raz.')
        #Użytkownik powinien wprowadzić tekst
        elif self.oczekiwanaOdp == 'zmienna_string':
            try:
                self.parametrDodatkowy = self.odpowiedz
                self.pozycjaMenu.append(0)
                print(f'\nTwój wybór to: {self.odpowiedz}')
            except:
                print('\nUps! Podałeś niepoprawną odpowiedź. Wyświetlę dla Ciebie menu jeszcze raz.')
        
        #Sprawdzenie czy wybrana opcja znajduje się w menu
        
        #Połącz wartości listy zawierającej pozycję w menu, aby móc przeszukać słownik menu
        pozycjaMenuString = ''.join([str(i) for i in self.pozycjaMenu])
        if not pozycjaMenuString in self.menu.keys():
            del self.pozycjaMenu[-1]
            print('\nUps! Podałeś niepoprawną odpowiedź. Wyświetlę dla Ciebie menu jeszcze raz.')
    
    #Wykonaj polecenie przypisane do danego poziomu menu. 
    def Wykonaj(self):
        #połącz wartości listy zawierającej pozycję w menu, aby móc przeszukać słownik menu
        pozycjaMenuString = ''.join([str(i) for i in self.pozycjaMenu])
    
        if self.menu[pozycjaMenuString]['typ'] == 'menu':
            #Wyświetl obecny poziom menu
            print(f'Poziom menu: {len(pozycjaMenuString) + 1}')
            #Wyświetl tekst menu
            print(self.menu[pozycjaMenuString]['tekst'])
            #Zapamiętaj typ kolejnej oczekiwanej odpowiedzi
            self.oczekiwanaOdp = self.menu[pozycjaMenuString]['oczekiwanaOdp']
        elif self.menu[pozycjaMenuString]['typ'] == 'akcja':
            #Wykonaj polecenie przypisane do obecnego miejsca w menu
            self.WykonajAkcje(self.menu[pozycjaMenuString]['akcja'])
            #Po wykonaniu polecenia wróć do ostatniego menu
            del self.pozycjaMenu[-1]
            #Wyświetl ostatnie menu
            self.Wykonaj()
    
        
    
    def sentiment_vader(self, sentence):
        sid = SentimentIntensityAnalyzer()
        snt = sid.polarity_scores(sentence)["compound"]
        if snt >= 0:
            return 1
        else:
            return 0
    
    
    def sentiment_vader_neutral(self, sentence):
        sid = SentimentIntensityAnalyzer()
        vs = sid.polarity_scores(sentence)["compound"]
        if vs == 0:
            return "Zdanie neutralne"
        elif vs > 0:
            return "Zdanie pozytywne"
        else:
            return "Zdanie negatywne"
    
    
    def sentiment_text_blob(self, sentence): 
        analysis = TextBlob(sentence)
        if analysis.sentiment.polarity >= 0: 
            return 1
        else:
            return 0
    
    
    def sentiment_text_blob_neutral(self, sentence): 
        analysis = TextBlob(sentence)
        if analysis.sentiment.polarity == 0: 
            return "Zdanie neutralne"
        elif analysis.sentiment.polarity > 0:
            return "Zdanie pozytywne"
        else:
            return "Zdanie negatywne"
    
    
    #Metoda do wykonywania poleceń w zależności od obecnego miejsca w menu
    def WykonajAkcje(self, akcja):
        if akcja == 'akcja_11':
            print("Wybrałeś opis danych:\n")
            print("Dane pochodzą ze strony: \n'www.kaggle.com/nicapotato/womens-ecommerce-clothing-reviews'\n")        
            print("Jest to zestaw danych E-Commerce dotyczący odzieży damskiej, zawierający recenzje klientów.")
            print("Z racji tego, że są to prawdziwe dane handlowe, zostały zanonimizowane, a odniesienia do firmy w tekście i treści przeglądu zostały zastąpione nazwą'sprzedawca detaliczny'\n")
            print("Ten zestaw danych zawiera 23486 wierszy i 10 zmiennych cech. Każdy wiersz odpowiada opinii klienta i zawiera zmienne:")
            print("Identyfikator odzieży, wiek klienta, tytuł komentarza, tekst komentarza, ocena, informacja o poleceniu/niepoleceniu produktu, liczba pozytywnych opinii, nazwa grupy, działu, kategorii ubrania\n")
        elif akcja == 'akcja_12':
            print("Wybrałeś podgląd pierwszych wierszy tabeli:\n")
            print(self.dane.head())
        elif akcja == 'akcja_13':
            print("Wybrałeś ogólne statystyki opisowe:\n")
            print(self.dane.describe())
        elif akcja == 'akcja_14':
            print("Wybrałeś podsumowanie danych:\n")
            print(self.dane.info())
        elif akcja == 'akcja_201':
            #Dodatkowo sprawdzenie czy wybrano poprawny numer kolumny
            try:
                print("LP.",self.kolumnyInt[self.parametrDodatkowy-1])
                print(self.dane[self.kolumnyInt[self.parametrDodatkowy-1]])
            except IndexError:
                print('Wybrałeś niepoprawną kolumnę. Wróć do poprzedniego menu i wybierz poprawny numer kolumny.')
        elif akcja == 'akcja_202':
            #Dodatkowo sprawdzenie czy wybrano poprawny numer kolumny
            try:    
                print(self.dane.loc[:,self.kolumnyInt[self.parametrDodatkowy-1]].describe())
            except IndexError:
                print('Wybrałeś niepoprawną kolumnę. Wróć do poprzedniego menu i wybierz poprawny numer kolumny.')
        elif akcja == 'akcja_203':
            #Dodatkowo sprawdzenie czy wybrano poprawny numer kolumny
            try:
                color = dict(markerfacecolor='r', marker='s')
                fig2, ax2 = plt.subplots()
                ax2.set_title(self.kolumnyInt[self.parametrDodatkowy-1])
                ax2.boxplot(self.dane[self.kolumnyInt[self.parametrDodatkowy-1]], notch=True, vert=False, flierprops=color)
                plt.show()
            except IndexError:
                print('Wybrałeś niepoprawną kolumnę. Wróć do poprzedniego menu i wybierz poprawny numer kolumny.')
        elif akcja == 'akcja_204':
            #Dodatkowo sprawdzenie czy wybrano poprawny numer kolumny
            try:
                sns.distplot(self.dane[self.kolumnyInt[self.parametrDodatkowy-1]])
                plt.show()
            except IndexError:
                print('Wybrałeś niepoprawną kolumnę. Wróć do poprzedniego menu i wybierz poprawny numer kolumny.')
        elif akcja == 'akcja_205':
            #Dodatkowo sprawdzenie czy wybrano poprawny numer kolumny
            try:
                sns.distplot(self.dane[self.kolumnyInt[self.parametrDodatkowy-1]], kde=True,kde_kws={"color": "b", "alpha":0.3, "linewidth": 5, "shade":True })
                plt.show()
            except IndexError:
                print('Wybrałeś niepoprawną kolumnę. Wróć do poprzedniego menu i wybierz poprawny numer kolumny.')
        elif akcja == 'akcja_31':
            dane_string = self.dane
            dane_string["Review Text"]=pd.Series(self.dane["Review Text"].fillna("0"))
            print("{} % klientów poleca zakupiony produkt".format(round(dane_string["Recommended IND"].mean()*100,2)))
            print("Średnia ocena produktów: {}".format(round(dane_string["Rating"].mean(),2)))
            print("\nW przypadku braku komentarza:")
            print("{} % klientów poleca zakupiony produkt".format(round(dane_string[dane_string["Review Text"]=="0"]["Recommended IND"].mean()*100,2)))
            print("Średnia ocena produktów: {}".format(round(dane_string[dane_string["Review Text"]=="0"]["Rating"].mean(),2)))
            print("\nNajdłuższy komentarz ma {} znaków".format(round(pd.Series(dane_string["Review Text"].str.len()).max(),0)))
            print("Średnia liczba znaków w komentarzach: {}".format(round(pd.Series(dane_string["Review Text"].str.len()).mean(),0)))
            
            
        elif akcja == 'akcja_320':
            num = input('Podajaj liczbę z przedziału (1-23485), aby przeczytać konkretny\n')
            try:
                num = int(num)
                if num > 0 and num <= 23485:
                    dane_string = self.dane
                    dane_string["Review Text"]=pd.Series(self.dane["Review Text"].fillna("0"))
                    text = dane_string["Review Text"][num-1]
                    rekomendacja = dane_string["Recommended IND"][num-1]
                    print(f"Komentarz numer {num}:\n\n {text}")
                    print(f"\nRekomendajca klienta: {'Tak' if rekomendacja == 1 else 'Nie'}")
                    print(f"\nRekomendacja według biblioteki Text Blob: {'Tak' if self.sentiment_text_blob(text)== 1 else 'Nie'}")
                    print(f"\nRekomendacja według biblioteki Vader Sentiment: {'Tak' if self.sentiment_vader(text) == 1 else 'Nie'}")
                    
                else:
                    print("Podałeś złą wartość")
            except ValueError:
                print(f"{num} - nie jest poprawną warością")
            
        elif akcja == 'akcja_330':
            slowo = input("Wyszukaj komentarze zawierające podane słowo: ")
            dane_string = self.dane
            dane_string["Review Text"]=pd.Series(self.dane["Review Text"].fillna("0"))
            pd.set_option('display.max_colwidth', -1)
            wynik_index = dane_string['Review Text'].str.contains(slowo)
            if dane_string["Review Text"][dane_string.index[wynik_index]].empty:
                print(f"Nie znaleziono komentarza ze slowem {slowo}") 
            else:
                print(dane_string["Review Text"][dane_string.index[wynik_index]]+ "\n")
        elif akcja == 'akcja_34':
            dane_string = self.dane
            dane_string["Review Text"]=pd.Series(self.dane["Review Text"].fillna("0"))
            text = ' '.join(dane_string["Review Text"])
            wordcloud = WordCloud(width=600, height=300).generate(text)
            plt.figure( figsize=(10,5), facecolor='k')
            plt.imshow(wordcloud)
            plt.axis("off")
            plt.tight_layout(pad=0)
            plt.show()
        elif akcja == 'akcja_350':
            sentencja = input("Podaj sentencję: \n")
            print(f"Według biblioteki Vader: {self.sentiment_vader_neutral(sentencja)}")
            print(f"Według biblioteki Text Blob: {self.sentiment_text_blob_neutral(sentencja)}")
        else:
            print('Coś poszło nie tak jak powinno. Wyświetlę dla Ciebie menu jeszcze raz.')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from textblob import TextBlob
import seaborn as sns
import numpy as np
from wordcloud import WordCloud
# %matplotlib inline

# %%
#Stworzenie obiektu klasy
NaszProgram = ProgramZCzasem('/home/sokal/Documents/DataScienceKurs/Python/Womens Clothing E-Commerce Reviews.csv')
#Wyświetlenie obecnego poziomu menu
NaszProgram.Wykonaj()

#Uruchomienie programu w pętli
while NaszProgram.ProgramDziala:
    NaszProgram.poprosOOdp()
    NaszProgram.zwalidujOdpowiedz()
    NaszProgram.Wykonaj()
# Out:
# Poziom menu: 1
#
# Menu początkowe:
# 1 - Ogólne informacje o danych
# 2 - Szczegółowe informacje o kolumnach typu integer
# 3 - Szczegółowe informacje o kolumnach typu string
# W każdym momencie wybierz:
# Z - aby przejść do poprzedniego menu
# X - aby wyjść z programu
#
# ################Twoj wybor:3
#
# Twój wybór to: 3
# Poziom menu: 2
#
# Chcesz się bliżej przyjrzeć komentarzom? Super!
# Przed Tobą kilka możliwości:
# 1 - Informacje statystyczne o komentarzach
# 2 - Przeczytaj konkretny komentarz
# 3 - Wyszukaj komentarze zawierające konkretne słowo
# 4 - Zobacz chmurę najpopularniejszych słów w komentarzach
# 5 - Przetestuj biblioteki oceniające, czy dany tekst jest pozytywny, czy negatywny, wpisując własną sentencje
#
# ################Twoj wybor:4
#
# Twój wybór to: 4
# Poziom menu: 2
#
# Chcesz się bliżej przyjrzeć komentarzom? Super!
# Przed Tobą kilka możliwości:
# 1 - Informacje statystyczne o komentarzach
# 2 - Przeczytaj konkretny komentarz
# 3 - Wyszukaj komentarze zawierające konkretne słowo
# 4 - Zobacz chmurę najpopularniejszych słów w komentarzach
# 5 - Przetestuj biblioteki oceniające, czy dany tekst jest pozytywny, czy negatywny, wpisując własną sentencje
#
# ################Twoj wybor:5
#
# Twój wybór to: 5
# Podaj sentencję:
# Z
# Według biblioteki Vader: Zdanie neutralne
# Według biblioteki Text Blob: Zdanie neutralne
# Poziom menu: 2
#
# Chcesz się bliżej przyjrzeć komentarzom? Super!
# Przed Tobą kilka możliwości:
# 1 - Informacje statystyczne o komentarzach
# 2 - Przeczytaj konkretny komentarz
# 3 - Wyszukaj komentarze zawierające konkretne słowo
# 4 - Zobacz chmurę najpopularniejszych słów w komentarzach
# 5 - Przetestuj biblioteki oceniające, czy dany tekst jest pozytywny, czy negatywny, wpisując własną sentencje
#
# ################Twoj wybor:5
#
# Twój wybór to: 5
# Podaj sentencję:
# hello
# Według biblioteki Vader: Zdanie neutralne
# Według biblioteki Text Blob: Zdanie neutralne
# Poziom menu: 2
#
# Chcesz się bliżej przyjrzeć komentarzom? Super!
# Przed Tobą kilka możliwości:
# 1 - Informacje statystyczne o komentarzach
# 2 - Przeczytaj konkretny komentarz
# 3 - Wyszukaj komentarze zawierające konkretne słowo
# 4 - Zobacz chmurę najpopularniejszych słów w komentarzach
# 5 - Przetestuj biblioteki oceniające, czy dany tekst jest pozytywny, czy negatywny, wpisując własną sentencje
#
# ################Twoj wybor:3
#
# Twój wybór to: 3
# Wyszukaj komentarze zawierające podane słowo: zero
# 56       I am pregnant and i thought this would be a great sleep bra. it's soft and fits okay, but it has zero support or shape. i would only buy if you are a b cup or smaller and can get away without support. if i would have seen this is the store, i would have passed over it. however, i was too lazy to return so i am wearing it. it's comfortable so that's a redeeming quality. i would not recommend for larger chested ladies, though!\n
# 127      This coat is beautiful! i love the color and the design. it definitely runs a little large. i usually wear a small or a zero and i can wear a small wth a large sweater underneath no problem. i might have wanted an extra small but i just stuck with the small because i needed the coat already. the vest keeps it warm, but the sleeves aren't lined so it's cold unless you have a nice sweater underneath it if you're going to be in cold weather.\n
# 258      Fits well through the shoulders and arms, but there is zero waist, and it just looks like a bunch of extra fabric hanging from the top. super cute, but have to return because of that.\n
# 694      After reviewing the comments for this dress i was really hesitant about buying it online, so i finally went to the store and all of the reviews are 100% true. this dress is amazing in terms of quality, but the sizing makes zero sense. i'm normally a size 12, but based on the reviews i initially tried on a medium. even that was huge, arm holes so long you could see my entire bra. so i tried on the small and that fit perfectly. unfortunately, unless you're normally an 8(maybe) or above in sizing,\n
# 870      I am 5 feet and 120. i ordered a petite small in moss. i have posted a photo below. it's a pretty green. the lining is pretty. the reason i deducted a star is because the lining is very thin and "slips" a little when putting the jacket on. but it doesn't effect the way the jacket falls and i wear it comfortably. it's floppy, but not sloppy. i was surprised that each side the fabric is like a tulip. it was a nice surprise. i'm curvy and busty. i have zero problem with it being unflattering. the s\n
# 918      These pants are 100% true to size (whatever that means anymore...i'm a 26 in paige and ag.  i'm 5''6, weigh around 115, have long legs and i ordered the 0p.  the zero petite are still a little long, with a slight heel they're perfect.  they don't have stretch in them, but do to the fit and fabric...the material does expand, because they're thin and breezy.  i absolutely love them.  can't wait to order other colors of the same style.  these are my new favorite pants.\n
# 1147     L space is frustrating. i wear a 0/2 top but with 32d's i tried a large in this bikini top because from past experience with l space they run small. there's just zero support. the tie design helps secure the girls in place, but also flattens them out if you tie it tight enough so you don't spill out.\n
# 2503     I loved this coat in the picture, and couldn't wait to get it. sadly, it did not deliver in real life. i got my usual size small, and it fit well in the shoulders and sleeves, and okay in front. the big problem was the back. it just hung from my shoulders with zero shape, and a lot of extra fabric. i considered trying the xs, but was concerned that the shoulders might not be comfortable, and honestly i can't believe the xs could possibly have been different enough to work. maybe i got a defectiv\n
# 3287     This is a fantastic dress for fall, if you have specific proportions. the dress comes in s-m-l, rather than in particular dress sizes, so my assumption was that a large would fit a range of 10-12. the dress fits me well in the fitted waist (which has zero give), but the top fits very strangely (you can even detect it on the model in the photo), with a tightness at the clavicle, and a weird abundance of fabric above the waistband.\r\n\r\ni will still happily wear the dress with sweaters this season,\n
# 4770     I'm on the smaller end of the bust spectrum even nursing i'm a 32c/d at my fullest. i adore this suit. there is zero support so if you need that move on don't buy this. i love it -hides the post partum baby puff, pattern detracts from flaws, deep plunge is modest yet still sexy and it's super stretchy and easily be pulled aside to feed a baby. underneath there's a fabric bra insert so if you bend over nothing can be seen which i like. haven't worn in water or waves yet but fabric feels awesome.\n
# 4846     I bought this shirt in the black cat print. the material is very soft and it has a nice drape. i wear a size 32dd and worried that the size zero may be too small across the bust but it fits perfectly. i am 5 feet tall with a petite frame. the front of the shirt falls a few inches below my waistline and the back of the shirt is longer and provides plenty of coverage so it can be worn with skinny jeans. i can also wear this to work with a pair of slacks and it looks nice. i would actually love to\n
# 5088     I've never had a problem with pilcro jeans. i own several pairs. however, i ordered my regular size 28 (i'm 5'3, 120 pounds) and not only were these jeans thin, they had zero stretch and after 1 hour of wear stretched out horribly. they fit really loose and hung around my knees and legs which is very disappointing for a skinny jean.\n
# 5337     I am five foot tall, about 103lb and got the petite zero - it fits perfectly and i love the flower pattern! great for weddings, parties or work.\n
# 6284     Saw this online when it first came up and thought it looked lovely. i purchased a different pleated dress and decided i didn't need a second pleated dress. was at my local retailer and they had one pink dress in a size 4 and a blue in a 0. decided to try them both on. the zero actually fit perfectly and at the sale price i had to have it. the material is beautiful, little details like the ruffled hem are lovely. one i will wear for years. thinking about getting the link but the blue is lovely. i'm\n
# 6396     These looked so cute and colorful! very sad to receive them yesterday and having to return them today. cute overall, but run large. depending on cut/style, i range from 2-4 in bottoms. i ordered a 2 in these, and they were just way too big. i would exchange for a zero, but i bought them for a trip this weekend. oh well.... consequence of online shopping!\n
# 7042     I typically wear xs or s, or zeros but i got this in a m.  it doesn't look big, it looks like a regular fit to me i think a small or xs would have looked and felt small.  it's soft beautiful and warm.  the hood is so cute.  the detail is just so good.  i love it over top of 2 long sleeve blouses i got there and one of the cloth and stone button downs.\n
# 7157     Like other reviewers have stated, this dress does run small on the chest. i'm 5.3", 32c, 120lbs and size 2 fits me great. however, if my chest size had been, like 34d and up, size 2 will not fit me although i'm petite frame. so, if you have a large chest, i would recommend going 1 or 2 sizes up. if you are like myself, small bust person, then you should try your regular size and one size down to see which one fits you better. i was going to try size zero, however as soon as i tried size 2, i rea\n
# 8293     Just piping in here -- ordered my usual size of small petite. the slip that came with the dress is about a size negative zero, it could hardly squeeze over my body and the dress itself is a bright pale aqua and it is a shift. and because of the smocking it hangs very strangely. i think it looks very cheap and is ill fitting. i would say if you are a person on which shift dresses look awesome you might like this, but mind the size of the slip in the petites range, and also it is aqua.\n
# 8722     I'm consistently a 0p in this brand, but i ordered a regular zero, and i'm glad i did not get the petite because it would have been too cropped for me. it's a bit boxy, and the material is thicker than i thought, but it is a versatile piece that look forward to wearing!\n
# 11677    Gosh, this is a beauty! maeve can be a little iffy on sizing, but i find this to fit tts. beautiful details, fit is comfortable yet elegant, nice length...i have zero complaints on this. it is sheer enough to need something underneath, but the fabric is lightweight enough that the extra layer doesn't seem bothersome. nice quality piece (not overly delicate despite the lacy details and sheerish fabric).\n
# 12275    I loved this dress when i saw it online! i could not wait until i see in one of the local stores.  i bought it today! unlike other reviews, i think this dress runs large. i am a 4 and bought the zero. maeve tends to run large on me. i would suggest that you try a size smaller. it looks very flattering!\n
# 14964    I loved the look of this top online - it had great lines. i was so disappointed when i received it.  it has zero support/lining and i'm not large chested to need a lot. it's also incredibly awkward to get on and the tie in the back is only long enough to knot it, making it even harder to get off. it was returned.\n
# 14979    This suit did nothing for me. the top has zero support. this would work for a younger woman who does not require any support and is smaller chested. also, the top gapped in the center. it just did not fit right. the top is very thin showing everything. a light padding would make a big difference in this suit. also i could not get a good fit. as i tightened the top, the back would ride up. the bottoms are ok. not renatkable\n
# 16258    The fabric of this looks and feels so cheap it's hard to believe this is anna sui. i would say this is unwearable. there is zero stretch and it is made of itchy textured poly fabric that looks like novelty fabric at best. going back asap.\n
# 17468    Got the coral reef color in a size medium. for reference, i say i am 5' 4" because its easier than explaining that i am really 5' 3 and 3/4", 138-140 lbs., 36c bra. size-wise, i am all over the place. recently i lost weight and have been buying smalls and mediums and anywhere from an 8 to a 12 from retailer. i so wanted to love this suit and am still in love with the fabric and colors. everything in the medium fit except for the bra cups. i am not especially big but there was zero cup room.\n
# 18063    The print on this dress is gorgeous---but the material does not stretch whatsoever, and there are not zippers or buttons to ease in the fit. i always, always, always wear a size zero. it was a massive struggle to even get the dress over my head and on to my body. i felt like i was getting crushed! once on, although awfully small, the dress is just beautiful in every way. so chic! i just returned it and ordered two sizes up---here's hoping it fits!\n
# 18241    This is so pretty and 60s like. i tried on a return size 2 and it really fit. i am usually a zero so i was surprised. the regular size fit me really well. length was perfect. pretty heavy and substantial though. love the 3 d effect. 115 lbs. 30 dd. 26.5 in waist\n
# 18764    I am 135 and went with a size zero. it was very cute on but a little tight on my hips when sitting. the fabric is beautiful, and very soft and silky. the length was great, comes to just barely above my knees and is long in the back. great work outfit.\n
# 19211    This dress is stunning, no doubt - a shimmering forest green under a black teardrop motif, thick material, nicely cut, with pocket panels that are forgiving to a belly. however, the fact that this dress has zero stretch (which is fine, if that's what you're looking for), coupled with what is quite possibly the cheapest zipper ever manufactured, make this dress exhausting to put on. i'm normally a 14/16 at retailer, and i ordered the 16 just to be safe, and the waist is exactly the size of my waist\n
# 20607    This suit is so beautiful, and the quality is great. i wanted it to work out, but unfortunately my chest size is not compatible with this bathing suit. i am a 36c and there is zero support (which i assumed when i ordered it, but it was so lovely in the photo i had to give it a try). for those who have a smaller bust, or are more comfortable with a little sexy side profile, this may be perfect. i ordered the large, and the bottoms were a good fit. i am also very petite and the length was good one\n
# 22569    This dress is really beautiful in person. it comes with a spaghetti strap clingy cotton slip underneath. it runs at least 2 sizes large. i tried my usual size 6 and needed to go down to a zero.\n
# 22771    I just got these leggings yesterday and honestly they're amazing. they look just like the picture, feel great on, don't slip in the waist. zero negatives. i can't wait to wear these bad boys out.\n
# 23307    Adorable skirt but fit is definitely too tight like the other reviews before me \r\n i am super petite 4 11 105 pounds the double zero and zero were just a little tight for me and a little too long ( both could fit around my waist which is a 24 but high waisted and tight not a fit around the hips)\r\n if  the length had been above the knee i might have kept  the zero but they were both returned \r\n great skirt in the theory  with the wrong  waste fit and length\n
# 23323    I just got this shirt the other day at the store.\r\nto my surprise i needed a size zero. i usually wear a size 4 or small never that small. \r\ni am 5'4 and a 34dd and it was still a little loose!! i bought the blue and brown color combination.\r\nit looked really cute on with a pair of white jeans for summer.\n
# Name: Review Text, dtype: object
# Poziom menu: 2
#
# Chcesz się bliżej przyjrzeć komentarzom? Super!
# Przed Tobą kilka możliwości:
# 1 - Informacje statystyczne o komentarzach
# 2 - Przeczytaj konkretny komentarz
# 3 - Wyszukaj komentarze zawierające konkretne słowo
# 4 - Zobacz chmurę najpopularniejszych słów w komentarzach
# 5 - Przetestuj biblioteki oceniające, czy dany tekst jest pozytywny, czy negatywny, wpisując własną sentencje
# ################Twoj wybor:2
#
# Twój wybór to: 2
# Poziom menu: 3
# Podaj numer z przedziału (1-23485), aby przeczytać konkretny komentarz.
